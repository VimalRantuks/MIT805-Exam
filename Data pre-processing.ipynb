# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv("C:/SparkCourse/Liquor Sales/Iowa_Liquor_Sales.csv")
# Out:
# C:\Users\ranch\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (6,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df1
# Out:
#          Invoice/Item Number        Date  Store Number  \
# 0               S24127700024  02/19/2015          3678
# 1               S15066200002  10/10/2013          2633
# 2               S19323500030  06/03/2014          2607
# 3               S23334500013  01/06/2015          4810
# 4               S09742200010  12/27/2012          4025
# ...                      ...         ...           ...
# 19666758        S10600200004  02/13/2013          3864
# 19666759        S23597800012  01/21/2015          5065
# 19666760        S29278700041  11/24/2015          3400
# 19666761        S04908000004  04/05/2012          2579
# 19666762        S09763500040  12/28/2012          4265
#
#                                     Store Name                   Address  \
# 0                              Smoke Shop, The           1918 SE 14TH ST
# 1                 Hy-Vee #3 / BDI / Des Moines           3221 SE 14TH ST
# 2         Hy-Vee Wine and Spirits / Shenandoah            520 SO FREMONT
# ...

# %%
df1.dtypes
# Out:
# Invoice/Item Number       object
# Date                      object
# Store Number               int64
# Store Name                object
# Address                   object
# City                      object
# Zip Code                  object
# Store Location            object
# County Number            float64
# County                    object
# Category                 float64
# Category Name             object
# Vendor Number            float64
# Vendor Name               object
# Item Number               object
# Item Description          object
# Pack                       int64
# Bottle Volume (ml)         int64
# State Bottle Cost        float64
# State Bottle Retail      float64
# Bottles Sold               int64
# Sale (Dollars)           float64
# Volume Sold (Liters)     float64
# Volume Sold (Gallons)    float64
# dtype: object

# %%
df2 = df1[["Date","Vendor Number","Item Number","Sale (Dollars)"]]

# %%
df2
# Out:
#                 Date  Vendor Number Item Number  Sale (Dollars)
# 0         02/19/2015          380.0       41783           14.68
# 1         10/10/2013          305.0      904969          134.94
# 2         06/03/2014          434.0       45277           78.12
# 3         01/06/2015           35.0       43121            8.31
# 4         12/27/2012          260.0       11298           92.98
# ...              ...            ...         ...             ...
# 19666758  02/13/2013          421.0       59231           54.78
# 19666759  01/21/2015          421.0       64863           20.00
# 19666760  11/24/2015          380.0       37336          117.00
# 19666761  04/05/2012           35.0       43128          132.00
# 19666762  12/28/2012          192.0       65256           54.18
#
# [19666763 rows x 4 columns]

# %%
event_null = df2['Date'].isnull().values.any()
user_null = df2['Vendor Number'].isnull().values.any()
item_null = df2['Item Number'].isnull().values.any()
price_null = df2['Sale (Dollars)'].isnull().values.any()
print(f"Date: {event_null}\nVendor: {user_null}\nItem: {item_null}\nPrice: {price_null}")
# Out:
# Date: False
# Vendor: True
# Item: False
# Price: True

# %%
df2.dropna(subset = ["Vendor Number"], inplace=True)
# Out:
# <ipython-input-8-757daf7f91ab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(subset = ["Vendor Number"], inplace=True)

# %%
df2.dropna(subset = ["Sale (Dollars)"], inplace=True)
# Out:
# <ipython-input-9-78cdec89765e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(subset = ["Sale (Dollars)"], inplace=True)

# %%
event_null = df2['Date'].isnull().values.any()
user_null = df2['Vendor Number'].isnull().values.any()
item_null = df2['Item Number'].isnull().values.any()
price_null = df2['Sale (Dollars)'].isnull().values.any()
print(f"Event time: {event_null}\nUser id: {user_null}\nItem: {item_null}\nPrice: {price_null}")
# Out:
# Event time: False
# User id: False
# Item: False
# Price: False

# %%
df2
# Out:
#                 Date  Vendor Number Item Number  Sale (Dollars)
# 0         02/19/2015          380.0       41783           14.68
# 1         10/10/2013          305.0      904969          134.94
# 2         06/03/2014          434.0       45277           78.12
# 3         01/06/2015           35.0       43121            8.31
# 4         12/27/2012          260.0       11298           92.98
# ...              ...            ...         ...             ...
# 19666758  02/13/2013          421.0       59231           54.78
# 19666759  01/21/2015          421.0       64863           20.00
# 19666760  11/24/2015          380.0       37336          117.00
# 19666761  04/05/2012           35.0       43128          132.00
# 19666762  12/28/2012          192.0       65256           54.18
#
# [19666748 rows x 4 columns]

# %%
df2.dtypes
# Out:
# Date               object
# Vendor Number     float64
# Item Number        object
# Sale (Dollars)    float64
# dtype: object

# %%
df2.describe()
# Out:
#        Vendor Number  Sale (Dollars)
# count   1.966675e+07    1.966675e+07
# mean    2.603095e+02    1.348577e+02
# std     1.401364e+02    4.643884e+02
# min     1.000000e+01    0.000000e+00
# 25%     1.150000e+02    3.150000e+01
# 50%     2.600000e+02    7.152000e+01
# 75%     3.800000e+02    1.393200e+02
# max     9.870000e+02    2.795573e+05

# %%
df2.to_csv('C:/SparkCourse/Liquor Sales/Liquor_Sales.csv', index=False)
